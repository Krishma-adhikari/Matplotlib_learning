# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('forest-restoration-tracking-1.csv')
df.head()
# Out:
#            SiteName GISPropNum InitPlntSn  Acreage DtaColMthd  \
# 0  Inwood Hill Park       M042       1995    0.092    Drawing
# 1  Inwood Hill Park       M042       1995    0.137    Drawing
# 2  Inwood Hill Park       M042       1995    0.178    Drawing
# 3  Inwood Hill Park       M042  2000 Fall    0.041    Drawing
# 4               NaN       M042       1997    0.105    Drawing
#
#                                                Shape
# 0  0xD70800000104050000008032436761A72E4100F873F1...
# 1  0xD70800000104050000000044E2D171A62E410024CCEE...
# 2  0xD70800000104050000008002BAA60FA52E4100C67A47...
# 3  0xD708000001040500000080109244BEAF2E4100422879...
# 4  0xD7080000010406000000006A8B625DA22E4100EEFD2A...

# %%
df.value_counts().sum()
# Out:
# np.int64(1513)

# %%
df.shape
# Out:
# (1541, 6)

# %%
df.columns
# Out:
# Index(['SiteName', 'GISPropNum', 'InitPlntSn', 'Acreage', 'DtaColMthd',
#        'Shape'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# SiteName      22
# GISPropNum     2
# InitPlntSn     1
# Acreage        0
# DtaColMthd     3
# Shape          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(17)

# %%
df = df.drop_duplicates()
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_sorted = df.sort_values(by="Acreage", ascending=False)
df_sorted[["SiteName", "Acreage"]].head(10)
# Out:
#                                  SiteName  Acreage
# 1280  Flushing Meadows Park - Willow Lake   23.264
# 1325             Rockaway Community  Park    8.243
# 303            New York Botanical Gardens    7.173
# 567                           Marine Park    6.333
# 37                            Bronx River    5.553
# 1222                      Alley Pond Park    5.384
# 53                             Bronx Park    5.141
# 286                        Riverdale Park    5.041
# 1351             Penn & Fountain Landfill    4.916
# 1429                      Freshkills Park    4.560

# %% [markdown]
# # 1. Which sites are biggest (Acreage)

# %%
df["Acreage"].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 1524 entries, 0 to 1540
# Series name: Acreage
# Non-Null Count  Dtype
# --------------  -----
# 1524 non-null   float64
# dtypes: float64(1)
# memory usage: 23.8 KB

# %%
df["Acreage"].describe()
# Out:
# count    1524.000000
# mean        0.446028
# std         0.919522
# min         0.000000
# 25%         0.068000
# 50%         0.186500
# 75%         0.471000
# max        23.264000
# Name: Acreage, dtype: float64

# %%
plt.hist(df_sorted['Acreage'].head(20))
plt.title('Acreage(Univariate-top-10-data)',size = 20)
plt.plot()
# Out:
# []

# %% [markdown]
# # 2. Shape distribution (Polygon vs Point)

# %%
df["Shape"].value_counts().sum()
# Out:
# np.int64(1524)

# %%
df["Shape"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Shape"].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 1524 entries, 0 to 1540
# Series name: Shape
# Non-Null Count  Dtype
# --------------  -----
# 1524 non-null   object
# dtypes: object(1)
# memory usage: 23.8+ KB

# %%
df["Shape"].describe()
# Out:
# count                                                  1524
# unique                                                 1431
# top       0xD708000001040600000000709481C00E3041004A15C4...
# freq                                                      3
# Name: Shape, dtype: object

# %%
sns.countplot(df['Shape'].head(10))
plt.show()
# df['Shape'].head(5).value_counts().plot(kind = 'pie')

# %% [markdown]
# # 3. Most common planting seasons

# %%
print(df['InitPlntSn'].value_counts().sum())
# Out:
# 1523

# %%
print(df['InitPlntSn'].dtype)
# Out:
# object

# %%
df['InitPlntSn'].head(20).value_counts().plot(kind = 'pie')
plt.show()

# %% [markdown]
# # 4. Cross-check patterns

# %% [markdown]
# Compare Shape vs Acreage

# %%
sns.barplot(x = 'Acreage',y= 'Shape',data = df.head(5))
plt.show()

# %% [markdown]
# Compare InitPlntSn vs Acreage

# %%
sns.barplot(x = 'Acreage',y= 'InitPlntS',data = df.head(5))
plt.show()
